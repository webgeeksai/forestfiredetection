# %% [markdown]
# # Dectecing Forest Fires using CNN
#
# Make sure you set up two conda envs before you run this notebook

# %% [markdown]
# First we need to pre-process the dataset to a sutable 100x100 dimension matrix for the neural network.
# For this we make use of opencv the unprocessed data is in the ./uprocessed data folder and the processed
# data is in the ./data folder.
#
# The data is already been proecessed for you and you are not required to run this step.

# %%
import cv2
import os

# %%
def image_processing(raw_data,data_path,height,width):
    class_labels=[]
    category_count=0
    for i in os.walk(raw_data):
        if len(i[2])>0:
            counter=0
            images=i[2]
            class_name=i[0].strip('\\')
            print(class_name)
            path=os.path.join(data_path,class_labels[category_count])
            for image in images:
                im=cv2.imread(class_name+'\\'+image)
                print(image)
                im=cv2.resize(im,(height,width))
                if not os.path.exists(path):
                    os.makedirs(path)
                cv2.imwrite(os.path.join(path,str(counter)+'.jpg'),im)
                counter+=1
            category_count+=1
        else:
            number_of_classes=len(i[1])
            print(number_of_classes,i[1])
            class_labels=i[1][:]

# %% [markdown]
# <p style="color:red"> You can skip running the below block and if you did you need to sort out the images in the following folder structure</p>
# data=>(test,train,valid)=>(fire,forest)

# %%
height = 100
width = 100
raw_data = 'unprocessed-data'
data_path = 'data'
image_processing(raw_data, data_path, height, width)
# Out:
# 2 ['forest', 'forest fire']
# unprocessed-data\forest
# 1. deforestation-what-wwf-doing-introhi_107217.jpg
# 10. 31105585103_4c32392ac1_k.jpg
# 100. forest.jpg
# 101. 220px-forrest_in_northern_bohemia_-_les_na_severu_%c4%8cech.jpg
# 102. merlin_141448098_8c5466da-3709-48a6-a9c2-dabda74d5bf7-articlelarge.jpg
# 103. depositphotos_73982563_m-2015.jpg
# 104. forest_fire_fighter.jpg
# 105. latvian_forest_tomes_pagasts%2c_%c4%b6eguma_novads%2c_latvia.jpg
# 106. theforestscreenshot_08.jpg
# 107. forest-area-banner.jpg
# 108. 559672101517195076987621071193712n.jpg
# 109. gp03a12.jpg
# 11. estonian_forest_reasons_to_visit_sven_zacek.jpg
# 110. 180321155319_1_540x360.jpg
# 111. forest%20-%20hm44%20apr-2012%20trees%20.jpg
# 112. fseprd576671_tn.jpg
# 113. 1841517.jpg
# 115. forests-k6--621x414@livemint.jpg
# 116. hy_forestsciences_hires_0.jpg
# 117. longleafpineforestnorthcarolina.jpg
# 118. forest.jpg
# 119. the-forest.jpg
# 12. 5325.jpg
# 120. semievergreen.jpg
# 122. 772526270ea45caa5d837f9dc053fe3f3e1c38ca.jpg
# 123. climate-change-forests-square.jpg
# 125. shady-forest.jpg
# 126. 1534996079-forest_th.jpg
# 127. 2770_3.burnedforest.jpg
# 128. sjm-l-redwood-0926-03.jpg
# 129. 43183278252_d04aca2db4_o.jpg
# 13. ss_a37e6873baf869be91010b20c30a7e61e4b82cc1.1920x1080.jpg
# 131. bg-forest.jpg
# 133. ikea-forest.jpg
# 134. foresta-umbra-1-665x429.jpg
# 135. 4a2d9b9400000578-5499373-the_density_of_the_forest_is_believed_to_be_a_contributing_facto-m-1_1521042050169.jpg
# 136. greatmountain.jpg
# 137. 103055dsc0172ssw2-1024x685.jpg
# 138. 220px-forstarbeiten_in_%c3%96sterreich.jpg
# 139. sherwood_forest_%289541%29.jpg
# 41. image.jpg
# 42. forest%20fire.jpg
# 43. maxresdefault.jpg
# 45. 220px-2011-08-04_20_00_00_susie_fire_in_the_adobe_range_west_of_elko_nevada.jpg
# 46. uttarakhand-fire-7591.jpg
# 47. how-to-protect-your-home-from-forest-fire-1024x588.jpg
# 48. wildfire.jpg
# 5. 1342d936cea42df5c34d1245c7d384e218740b62f430731f92b0c76a1761fdcb.jpg
# 51. fire.jpg
# 52. gettyimages-862092472.jpg
# 54. 0.67221200_1524831102_fire.jpg
# 55. 14-understandin.jpg
# 56. fb62d7add05877b1f748c55d9f456206a1b93e8709c8b4b16bf23237c17155d6.jpg
# 57. 880x495_cmsv2_22f70141-4968-5b10-a1cf-36084c7f27ce-3225294.jpg
# 58. ff-deer-bbc-copy.jpg
# 59. bonsall-fire.jpg
# 6. wild-fires.jpg
# 60. 1527180902-forest_fires.jpg
# 61. tlumacki_whitemountainsforestfire_metro437.jpg
# 62. fire_647_050216042217.jpg
# 63. horseshoe-bay-fire.jpg
# 64. vbk-forest%20fire.jpg
# 65. 19496780.jpg
# 66. la-tuna-fire.jpg
# 67. p05fj8x8.jpg
# 68. dc_forestfire.jpg
# 69. 2017_06_12_14_43_25_1.jpeg
# 7. forest-fire.jpg
# 70. flickr_usda.jpg
# 71. forest-fire-2268729_1280.jpg
# 72. h6jf46.jpg
# 73. eucalyptus_forest_fire%2c_madeira%2c_portugal%2c_3_july_2011_-_panoramio_%283%29.jpg
# 74. how-do-forest-fires-start.jpg
# 76. forest620.jpg
# 77. lks%2019.7.2018%20maastopalo%20kittil%c3%a4%20rajaselk%c3%a4.jpg
# 78. 2016_09_26_12763_1474875686._large.jpg
# 79. dc-cover-dvge6ctblibun30ih6rv2peci4-20171104074212.medi.jpeg
# 8. shutterstock-48032821.jpg
# 80. forest-fire-432870_960_720.jpg
# 81. forest-fires-8-1.jpg
# 83. forest-fire-in-uttarakhand-india-1-638.jpg
# 84. 05_22_2013_forest-fire.jpg
# 85. gettyimages-495207966.jpg
# 86. 529781-uttarakhand3.jpg
# 87. portugal-fire_650x400_71497772164.jpg
# 88. in-forestfires-shutter.jpg
# 9. maxresdefault.jpg
# 90. forest-fire-story,-fb_647_050416082937.jpg
# 92. forest_fire_11_3_0.jpg
# 93. fighting-forest-fires.jpg
# 94. maxresdefault.jpg
# 95. aaf129c256d3a0d99f781bee17991f4bfcd90deb050f942d2b1a4918200940e1.jpg
# 96. f90-fire-1168x657.jpg
# 97. image.jpg
# 98. mironov.jpg
# 99. forestfire_191015.jpg

# %% [markdown]
# Here is a few sample images to see how the data looks like.
# <br><img src="./data/test/fire/68.jpg" style="display:inline"/><img src="./data/test/fire/88.jpg" style="display:inline"/><img src="./data/test/fire/107.jpg" style="display:inline"/><br>
# The dataset contains 600+ images in jpg format.

# %% [markdown]
# ### Step 1
# Lets start with importing our data and genrating some insights on it.
# The data is divided into train, test, validation sets with a split of aproximatly 60%, 20%, 20%.

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

def load_dataset(path):
    data = load_files(path)
    files = np.array(data['filenames'])
    targets = np_utils.to_categorical(np.array(data['target']), 133)
    return files, targets

train_files, train_targets = load_dataset('data/train')
valid_files, valid_targets = load_dataset('data/valid')
test_files, test_targets = load_dataset('data/test')

class_names = [item[11:-1] for item in sorted(glob("data/train/*/"))]

print('There are %d total categories.' % len(class_names))
print('There are %s total images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training images.' % len(train_files))
print('There are %d validation images.' % len(valid_files))
print('There are %d test images.'% len(test_files))
# Out:
# Using TensorFlow backend.
# There are 2 total categories.
# There are 606 total images.
#
# There are 386 training images.
# There are 110 validation images.
# There are 110 test images.

# %% [markdown]
# ### Step 2
# Next lets convert our 100x100x3 dimension image to a 1x100x100x3 tensor.

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    img = image.load_img(img_path, target_size=(100, 100))
    x = image.img_to_array(img)
    # converting to a tensor of dimensions (1,100,100,3)
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 386/386 [00:03<00:00, 119.61it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 110/110 [00:00<00:00, 1222.63it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 110/110 [00:00<00:00, 1133.33it/s]

# %% [markdown]
# ### Step 3
# Lets start builing our CNN model with keras

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

# %%
model = Sequential()
model.add(Conv2D(32,(3, 3),activation='relu',input_shape=train_tensors[0].shape))
model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid'))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(133, activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 98, 98, 32)        896
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 49, 49, 32)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 49, 49, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 47, 47, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 22, 22, 128)       73856
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 11, 11, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 15488)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                991296
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 133)               8645
# =================================================================
# Total params: 1,093,189.0
# Trainable params: 1,093,189.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Step 3
# In this step we train the model and store checkpoints.

# %%
from keras.callbacks import ModelCheckpoint  

epochs = 5
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 386 samples, validate on 110 samples
# Epoch 1/5
#  - ETA: 0s - loss: 0.7228 - acc: 0.7553Epoch 00000: val_loss improved from inf to 0.36491, saving model to saved_models/weights.best.from_scratch.hdf5
#  - 17s - loss: 0.7203 - acc: 0.7565 - val_loss: 0.3649 - val_acc: 0.8545
# Epoch 2/5
#  - ETA: 0s - loss: 0.4982 - acc: 0.7974Epoch 00001: val_loss did not improve
#  - 19s - loss: 0.5092 - acc: 0.7927 - val_loss: 0.6870 - val_acc: 0.8909
# Epoch 3/5
#  - ETA: 0s - loss: 0.4234 - acc: 0.8342Epoch 00002: val_loss did not improve
#  - 20s - loss: 0.4288 - acc: 0.8316 - val_loss: 0.3713 - val_acc: 0.8636
# Epoch 4/5
#  - ETA: 0s - loss: 0.3267 - acc: 0.8842Epoch 00003: val_loss improved from 0.36491 to 0.23601, saving model to saved_models/weights.best.from_scratch.hdf5
#  - 19s - loss: 0.3253 - acc: 0.8834 - val_loss: 0.2360 - val_acc: 0.8727
# Epoch 5/5
#  - ETA: 0s - loss: 0.4255 - acc: 0.8789Epoch 00004: val_loss improved from 0.23601 to 0.16672, saving model to saved_models/weights.best.from_scratch.hdf5
#  - 21s - loss: 0.4226 - acc: 0.8808 - val_loss: 0.1667 - val_acc: 0.9364

# %%
print(train_tensors.shape)
# Out:
# (386, 100, 100, 3)

# %%
predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]
test_accuracy = 100*np.sum(np.array(predictions)==np.argmax(test_targets, axis=1))/len(predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 94.5455%

# %% [markdown]
# ### Step 4
# Testing the with some images.
# <img src="fire.jpg"/>

# %%
img = cv2.imread('./fire.jpg')
img=cv2.resize(img,(100,100))
img = np.expand_dims(img, axis=0)

# %%
if model.predict(img)[0][1] == 1.0:
    print("Normal")
elif model.predict(img)[0][0] == 1.0:
    print("Fire")
# Out:
# Fire

# %% [markdown]
# ### Step6
# Exporting the model to model.json

# %%
model_json = model.to_json()

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ### Step 7
# Once you are done with this notebook you can try out the model with video stream by running test.py file.
# To run test.py you need to enable the second enviorment or you may encounter errors with OpenCV.
